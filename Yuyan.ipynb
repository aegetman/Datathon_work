# %%
import pandas as pd
import pyarrow
import os
# save and load data
import pickle
save_dir = "/saved_data"
wd = "/content/drive/MyDrive/Datathon"

def save_variable(variable, filename):
  f = open(filename, "wb")
  pickle.dump(variable, f)
  f.close()
  return filename

def load_variable(filename):
  f = open(filename, "rb")
  variable = pd.read_pickle(f)
  f.close()
  return variable

# %%
# Get the current directory
current_dir = os.getcwd()

# List all files in the directory
files = os.listdir(current_dir)

# Filter out the Parquet files
parquet_files = [file for file in files if file.endswith('.parquet.gzip') or file.endswith('.parquet')]

# Loop through each Parquet file, read it, and assign to a DataFrame
for file in parquet_files:
    # Construct the full file path
    file_path = os.path.join(current_dir, file)
    
    # Extract dataframe name from file name without extension
    dataframe_name = os.path.splitext(file)[0]
    # Remove the extension .gzip if present
    dataframe_name = dataframe_name.replace('.gzip', '')
    # Remove the extension .parquet if present
    dataframe_name = dataframe_name.replace('.parquet', '')
    # Add the _df suffix
    #dataframe_name += '_df'
    
    # Read the Parquet file into a DataFrame and assign it to a dynamically created variable
    globals()[dataframe_name] = pd.read_parquet(file_path)

    # Now you have individual variables named interventions_df, x_df, etc., each containing a DataFrame
    # You can directly access these DataFrames and perform operations on them, for example:
    print(f"DataFrame '{dataframe_name}' shape: {globals()[dataframe_name].shape}")
    print(globals()[dataframe_name].head())  # Example operation on the DataFrame
# Out:
# DataFrame 'aed_locations' shape: (15227, 11)
#      id  type                address  number  postal_code municipality  \
# 0  13.0  None    Blvd. Fr. Roosevelt    24.0       7060.0     SOIGNIES
# 1  70.0  None        Ch. De Wégimont    76.0       4630.0      Ayeneux
# 2  71.0  None  Place Saint - Lambert     NaN       4020.0        Liège
# 3  72.0  None          Rue du Doyard     NaN       4990.0     Lierneux
# 4  73.0  None     Fond Saint Servais     NaN       4000.0        Liège
#
#   province location public available hours
# 0  Hainaut     None      Y      None  None
# 1    Liège     None   None      None  None
# 2    Liège     None   None      None  None
# 3    Liège     None   None      None  None
# 4    Liège     None   None      None  None
# DataFrame 'ambulance_locations' shape: (279, 9)
#                                      base  \
# 0             BA ANTW [Borgerhout] AMBUCE
# 1                BA ANTW [Hoboken] AMBUCE
# 2  BA ANTW [Hof Ter Schelde] AC Antwerpen
# 3                BA ANTW [Kaai 606] SIHWA
# 4   BA ANTW [Sint Elisabeth] AC Antwerpen
#
#                                     medical_resource   province  \
# 0                   ZW ANTWERPEN 7 (Team: AAANTW07A)  Antwerpen
# 1                   ZW ANTWERPEN 9 (Team: AAANTW09A)  Antwerpen
# 2                   ZW ANTWERPEN 3 (Team: AAANTW03A)  Antwerpen
# 3  ZW ANTWERPEN HAVEN 1 (Team: AAAPOR01A)_x000D_Z...  Antwerpen
# 4                   ZW ANTWERPEN 2 (Team: AAANTW02A)  Antwerpen
#
#           region                         departure_location  \
# 0  Vlaams Gewest           Gijselstraat 150 2140 BORGERHOUT
# 1  Vlaams Gewest         Antwerpsesteenweg 242 2660 HOBOKEN
# 2  Vlaams Gewest      August Vermeylenlaan 6 2050 ANTWERPEN
# 3  Vlaams Gewest  Antwerpsebaan 4 (Kaai 606) 2040 ANTWERPEN
# 4  Vlaams Gewest            Leopoldstraat 26 2000 ANTWERPEN
#
#    departure_location_number   latitude  longitude occasional_permanence
# 0                       3811  51.215516   4.443788                     N
# 1                       3812  51.178831   4.361948                     N
# 2                      10902  51.232810   4.377237                     N
# 3                      12902  51.315516   4.321506                     N
# 4                      10901  51.213623   4.405718                     N
# DataFrame 'cad9' shape: (289401, 35)
#   province   Mission ID                 Service Name  Latitude permanence  \
# 0      VBR  21221520003             MV HVP VILV West            50.925277
# 1      VBR  21221520004             MV HVP HALL West            50.743200
# 2      VBR  21221520007             MV HVP VILV West            50.925277
# 3      VBR  21221520007   HV UR VILV AZ Jan Portaels            50.926869
# 4      VBR  21221520008  BB BRUX Hôpital Militair KA            50.905331
#
#    Longitude permanence Permanence short name Permanence long name  \
# 0              4.423057             AVVILV01A       ZW VILVOORDE 1
# 1              4.241053             AVHALL02A           ZW HALLE 2
# 2              4.423057             AVVILV01A       ZW VILVOORDE 1
# 3              4.420968             UVVILV01A        MUG VILVOORDE
# 4              4.387662             ABBRUX13A           AMB HMB 13
#
#   Vector Type                                  EventType Trip  \
# 0   Ambulance                            P034 - SCHEDELTRAUMA
# 1   Ambulance                 P010 - ADEMHALINGSMOEILIJKHEDEN
# 2   Ambulance  Y_TI BEVRIJDING PERSOON BEKLEMD/OPGESLOTEN+DGH
# 3         MUG  Y_TI BEVRIJDING PERSOON BEKLEMD/OPGESLOTEN+DGH
# 4   Ambulance                      P020 - INTOXICATIE ALCOHOL
#
#   EventSubType Trip  ...   Name destination hospital  \
# 0                 /  ...  HV UR VILV AZ JAN PORTAELS
# 1                 /  ...      HV UR HALL AZ ST MARIA
# 2                 /  ...  HV UR VILV AZ JAN PORTAELS
# 3                 /  ...  HV UR VILV AZ JAN PORTAELS
# 4                 /  ...                        None
#
#   Intervention time (T1Reported) Intervention time (T1Confirmed)  \
# 0                           10.0                             NaN
# 1                            7.0                             NaN
# 2                           10.0                             NaN
# 3                            7.0                             NaN
# 4                           14.0                             NaN
#
#    Departure time (T1Reported)  Departure time (T1Confirmed)  \
# 0                          2.0                           NaN
# 1                          3.0                           NaN
# 2                          4.0                           NaN
# 3                          1.0                           NaN
# 4                          7.0                           NaN
#
#                          UI        ID   MISSION_NR AMBUCODE    UNIT_ID
# 0  21221520003   1969661672  19189868  21221520003    240.0  MVVILV101
# 1  21221520004   1969661709  19189847  21221520004    240.0  MVHALL102
# 2  21221520007   1969664866  19190011  21221520007    240.0  MVVILV101
# 3  21221520007   1969665019  19190053  21221520007      0.0  MVVILV301
# 4  21221520008   1969665449  19189967  21221520008     39.0  MBMILH101
#
# [5 rows x 35 columns]
# DataFrame 'interventions1' shape: (200627, 46)
#     Mission ID                 Service Name  PostalCode permanence  \
# 0  10221520001     HA UR MECH AZ St Maarten                 2800.0
# 1  10221520002               BA KAPE AMBUCE                 2950.0
# 2  10221520002       HA UR ANTW Stuivenberg                 2060.0
# 3  10221520004  BA ANTW [Borgerhout] AMBUCE                 2140.0
# 4  10221520005               BA WIJN AMBUCE                 2110.0
#
#       CityName permanence   StreetName permanence HouseNumber permanence  \
# 0     Mechelen (Mechelen)          Liersesteenweg                   None
# 1     Kapellen (Kapellen)         Essenhoutstraat                   None
# 2   Antwerpen (Antwerpen)  Lange Beeldekensstraat                   None
# 3  Antwerpen (Borgerhout)           Gijselsstraat                   None
# 4     Wijnegem (Wijnegem)           Bijkhoevelaan                   None
#
#    Latitude permanence  Longitude permanence Permanence short name  \
# 0            51.051020              4.478030             AAMECH01A
# 1            51.312075              4.424398             AAKAPE01A
# 2            51.222490              4.436290             UAANTW01A
# 3            51.215620              4.443920             AAANTW07A
# 4            51.233550              4.493180             AAWIJN01A
#
#   Permanence long name  ... Unavailable time Name destination hospital  \
# 0        ZW MECHELEN 1  ...              NaN                      None
# 1        ZW KAPELLEN 1  ...              NaN    HA UR ANTW Jan Palfijn
# 2      MUG ANTWERPEN 1  ...              NaN                      None
# 3       ZW ANTWERPEN 7  ...              NaN                      None
# 4        ZW WIJNEGEM 1  ...              NaN    HA UR ANTW Jan Palfijn
#
#   PostalCode destination hospital CityName destination hospital  \
# 0                            None                          None
# 1                            None           Antwerpen (Merksem)
# 2                            None                          None
# 3                            None                          None
# 4                            None           Antwerpen (Merksem)
#
#   StreetName destination hospital HouseNumber destination hospital  \
# 0                            None                             None
# 1                Lange Bremstraat                             None
# 2                            None                             None
# 3                            None                             None
# 4                Lange Bremstraat                             None
#
#   Calculated travelTime destinatio  Calculated Distance destination  \
# 0                              NaN                              NaN
# 1                            678.0                          11743.0
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                            530.0                           5468.0
#
#    Number of transported persons        Abandon reason
# 0                            NaN  Verzorgd ter plaatse
# 1                            1.0                  None
# 2                            NaN                  None
# 3                            NaN        Zonder patient
# 4                            1.0                  None
#
# [5 rows x 46 columns]
# DataFrame 'interventions2' shape: (200627, 46)
#     Mission ID                       Service Name  PostalCode permanence  \
# 0  50221920087       FH PDS COMI Wallonie Picarde                 7784.0
# 1  50221920088       FH PDS TOUR Wallonie Picarde                 7500.0
# 2  50221920089         FH PDS LOUV Hainaut Centre                 7100.0
# 3  50221920090  FW HVP HEUV [Nieuwkerke] Westhoek                 8950.0
# 4  50221920092                BH SGHI Croix Rouge                 7331.0
#
#            CityName permanence      StreetName permanence  \
# 0  Comines-Warneton (Warneton)          Chauss√©e d'Ypres
# 1            Tournai (Tournai)            Avenue de Maire
# 2  La Louvi√®re (La Louvi√®re)  Boulevard du Roi Baudouin
# 3      Heuvelland (Nieuwkerke)            Dranouterstraat
# 4     Saint-Ghislain (Baudour)             Rue Louis Caty
#
#   HouseNumber permanence  Latitude permanence  Longitude permanence  \
# 0                   None             50.76034              2.940230
# 1                   None             50.61652              3.375120
# 2                   None             50.46800              4.192170
# 3                   None             50.74621              2.822500
# 4                   None             50.46963              3.842559
#
#   Permanence short name Permanence long name  ... Unavailable time  \
# 0             AHCOMI01A         ZS COMINES 1  ...              NaN
# 1             AHTOUR01A         ZS TOURNAI 1  ...              NaN
# 2             AHLOUV02A   ZS LA LOUVIERE PIM  ...              NaN
# 3             AWHEUV01A        ZW NIEUWKERKE  ...            604.0
# 4             AHSGHI01A  CR SAINT-GHISLAIN 1  ...              NaN
#
#                       Name destination hospital  \
# 0                                HH UR MOUS CHM
# 1          HH UR TOUR CH Wallonie Picarde Union
# 2                       HH UR LOUV CHU Jolimont
# 3                   HFR EX ARME CH Armenti√®res
# 4  HH UR BOUS CH Epicura (H√¥pital Grand Hornu)
#
#   PostalCode destination hospital    CityName destination hospital  \
# 0                            None              Mouscron (Mouscron)
# 1                            None                Tournai (Tournai)
# 2                            None  La Louvi√®re (Haine-Saint-Paul)
# 3                            None                 FRA-Armenti√®res
# 4                            None                   Boussu (Hornu)
#
#   StreetName destination hospital HouseNumber destination hospital  \
# 0               Avenue de F√©camp                             None
# 1                  Rue des Sports                             None
# 2                      Rue Ferrer                             None
# 3                 Rue Sadi Carnot                             None
# 4                 Rue du Commerce                             None
#
#   Calculated travelTime destinatio  Calculated Distance destination  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    Number of transported persons Abandon reason
# 0                            1.0           None
# 1                            1.0           None
# 2                            1.0           None
# 3                            NaN           None
# 4                            1.0           None
#
# [5 rows x 46 columns]
# DataFrame 'interventions3' shape: (200627, 46)
#     Mission ID                        Service Name  PostalCode permanence  \
# 0  60230050009                 BG LIEG Croix Rouge                 4000.0
# 1  60230050010  FG PDS PEPI Vesdre Ho√´gne Plateau                 4860.0
# 2  60230050012                    BG LIEG Courtois                 4030.0
# 3  60230050013             FG PDS ANS_ Li√®ge IILE                 4000.0
# 4  60230050014             FG PDS FLEM Li√®ge IILE                 4400.0
#
#            CityName permanence  StreetName permanence HouseNumber permanence  \
# 0              Li√®ge (Li√®ge)            Rue Darchis                   None
# 1        Pepinster (Pepinster)         Rue Jean Simon                   None
# 2          Li√®ge (Grivegn√©e)            Rue Belvaux                   None
# 3               li√®ge (glain)  p537;rue jean jaur√®s                   None
# 4  Fl√©malle (Fl√©malle-Haute)            Grand'Route                   None
#
#    Latitude permanence  Longitude permanence Permanence short name  \
# 0            50.637357              5.566551             AGLIEG05A
# 1            50.565940              5.802540             AGPEPI01A
# 2            50.619828              5.602470             AGLIEG02A
# 3            50.652240              5.526410             AGANS_01A
# 4            50.599360              5.472130             AGFLEM01A
#
#   Permanence long name  ... Unavailable time  Name destination hospital  \
# 0           CR LIEGE 2  ...              NaN                       None
# 1         ZS.PEPINST 1  ...              NaN    HG UR VERV CHR Tourelle
# 2            PR.COURT2  ...              NaN   HG UR LIEG CHC Montlegia
# 3             ZS ANS 1  ...              NaN                       None
# 4        ZS FLEMALLE 1  ...              NaN  HG UR SERA CH Bois Abbaye
#
#   PostalCode destination hospital CityName destination hospital  \
# 0                            None                          None
# 1                            None           Verviers (Verviers)
# 2                            None                Li√®ge (Glain)
# 3                            None                          None
# 4                            None             Seraing (Seraing)
#
#      StreetName destination hospital HouseNumber destination hospital  \
# 0                               None                             None
# 1                    Rue de la Marne                             None
# 2  Boulevard de Patience et Beaujonc                             None
# 3                               None                             None
# 4                        Rue Laplace                             None
#
#   Calculated travelTime destinatio  Calculated Distance destination  \
# 0                              NaN                              NaN
# 1                            461.0                           7398.0
# 2                            232.0                           3952.0
# 3                              NaN                              NaN
# 4                            227.0                           2794.0
#
#    Number of transported persons         Abandon reason
# 0                            NaN  Weigering van vervoer
# 1                            1.0                   None
# 2                            1.0                   None
# 3                            NaN   Verzorgd ter plaatse
# 4                            1.0                   None
#
# [5 rows x 46 columns]
# DataFrame 'interventions_bxl' shape: (115647, 45)
#     mission_id                   service_name  postalcode_permanence  \
# 0  20222490011  FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 1  20222490011  FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 2  20222490012       HB UR BRUX CHU St Pierre                   1000
# 3  20222490015  FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 4  20222490019   FB PDS WOLL [PASI UCL] SIAMU                   1200
#
#                            cityname_permanence  \
# 0                            Brussel (Brussel)
# 1                            Brussel (Brussel)
# 2                            Brussel (Brussel)
# 3                            Brussel (Brussel)
# 4  Woluwe-Saint-Lambert (Woluwe-Saint-Lambert)
#
#                  streetname_permanence housenumber_permanence  \
# 0                       Vesaliusstraat                   None
# 1                       Vesaliusstraat                   None
# 2                            Rue Haute                   None
# 3                       Vesaliusstraat                   None
# 4  Avenue Hippocrate - Hippokrateslaan                   None
#
#    latitude_permanence  longitude_permanence permanence_short_name  \
# 0              5085097                436411             ABBRUX11A
# 1              5085097                436411             ABBRUX03A
# 2            508343302              43454504             ABBRUX06A
# 3              5085097                436411             ABBRUX03A
# 4              5085211                 44604             ABWOLL01A
#
#   permanence_long_name  ... postalcode_destination_hospital  \
# 0           AMB CITE 2  ...                             NaN
# 1           AMB HELI 3  ...                          1000.0
# 2            AMB HSP 1  ...                             NaN
# 3           AMB HELI 3  ...                             NaN
# 4            AMB UCL 1  ...                             NaN
#
#   cityname_destination_hospital streetname_destination_hospital  \
# 0                          None                            None
# 1             Brussel (Brussel)                     Broekstraat
# 2                          None                            None
# 3                          None                            None
# 4                          None                            None
#
#   housenumber_destination_hospital calculated_traveltime_departure_  \
# 0                              NaN                             92.0
# 1                              NaN                             92.0
# 2                              NaN                             28.0
# 3                              NaN                              8.0
# 4                              NaN                            152.0
#
#    calculated_distance_departure_to calculated_traveltime_destinatio  \
# 0                             784.0                              NaN
# 1                             784.0                            136.0
# 2                             228.0                              NaN
# 3                              58.0                              NaN
# 4                            1905.0                              NaN
#
#    calculated_distance_destination_  number_of_transported_persons  \
# 0                               NaN                            NaN
# 1                            1330.0                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#           abandon_reason
# 0                  Error
# 1                   None
# 2                  Error
# 3  Weigering van vervoer
# 4            Geannuleerd
#
# [5 rows x 45 columns]
# DataFrame 'interventions_bxl2' shape: (38620, 36)
#     Mission ID                T0         Cityname Intervention  \
# 0  20221520003  01JUN22:00:02:45  1030 schaerbeek (schaerbeek)
# 1  20221520005  01JUN22:00:04:58  1030 schaerbeek (schaerbeek)
# 2  20221520006  01JUN22:00:07:43  1081 koekelberg (koekelberg)
# 3  20221520006  01JUN22:00:07:43  1081 koekelberg (koekelberg)
# 4  20221520007  01JUN22:00:09:18  1030 schaerbeek (schaerbeek)
#
#    Longitude intervention  Latitude intervention  description_nl  \
# 0            4.406731e+10           5.085516e+10  Nieuwe melding
# 1            4.368798e+10           5.086318e+10  Nieuwe melding
# 2            4.332312e+10           5.085755e+10  Nieuwe melding
# 3            4.332312e+10           5.085755e+10  Nieuwe melding
# 4            4.383695e+10           5.085225e+10  Nieuwe melding
#
#   ic_description_nl                           EventType and EventLevel  \
# 0           Medisch                                  P033 N05 - TRAUMA
# 1           Medisch                     P032 N05 - ALLERGISCHE REACTIE
# 2           Medisch                P010 N01 - ADEMHALINGSMOEILIJKHEDEN
# 3           Medisch                P010 N01 - ADEMHALINGSMOEILIJKHEDEN
# 4           Medisch  P039 N05 - CARDIAAL PROBLEEM (ANDERE DAN PIJN ...
#
#        creationtime  Number of transported persons  ...  \
# 0  01JUN22:00:04:06                            NaN  ...
# 1  01JUN22:00:07:54                            1.0  ...
# 2  01JUN22:00:12:05                            1.0  ...
# 3  01JUN22:00:11:50                            NaN  ...
# 4  01JUN22:00:11:37                            NaN  ...
#
#   Housenumber destination hospital  Abandon reason NL Abandon reason FR  \
# 0                             None  Weigering vervoer             Refus
# 1                             None               None              None
# 2                             None               None              None
# 3                             None               None              None
# 4                             None  Weigering vervoer             Refus
#
#                  T1                T2                T3                T4  \
# 0  01JUN22:00:04:22  01JUN22:00:15:56  01JUN22:00:15:59              None
# 1  01JUN22:00:08:00  01JUN22:00:10:03  01JUN22:00:19:43  01JUN22:00:19:49
# 2              None              None              None              None
# 3              None              None              None              None
# 4  01JUN22:00:12:05  01JUN22:00:13:03  01JUN22:00:20:29              None
#
#                  T5                T6                T7
# 0              None  01JUN22:00:38:06  01JUN22:00:43:54
# 1  01JUN22:00:24:25  01JUN22:01:59:18  01JUN22:01:59:19
# 2              None              None              None
# 3              None              None              None
# 4              None  01JUN22:00:34:11  01JUN22:00:55:36
#
# [5 rows x 36 columns]
# DataFrame 'mug_locations' shape: (94, 10)
#    hospital_id  mug_id  campus_id                      name_hospital  \
# 0            9  102000       6230  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 1           99  102000       2020                  GZA- ZIEKENHUIZEN
# 2          682  102000       1210                          AZ MONICA
# 3            9  103000       2000  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 4           99  103000       1290                  GZA- ZIEKENHUIZEN
#
#         name_campus           address_campus  postal_code municipality region  \
# 0         ZNA CADIX         KEMPENSTRAAT 100         2030    ANTWERPEN      V
# 1   SINT-VINCENTIUS  ST.-VINCENTIUSSTRAAT 20         2018    ANTWERPEN      V
# 2            DEURNE     FLORENT PAUWELSLEI 1         2100       DEURNE      V
# 3    ZNA MIDDELHEIM            LINDENDREEF 1         2020    ANTWERPEN      V
# 4  SINT- AUGUSTINUS        OOSTERVELDLAAN 24         2610      WILRIJK      V
#
#     province
# 0  Antwerpen
# 1  Antwerpen
# 2  Antwerpen
# 3  Antwerpen
# 4  Antwerpen
# DataFrame 'pit_locations' shape: (24, 8)
#                                  unit  \
# 0    100001: PIT Rumst, AZ Rivierland
# 1  102001: PIT Deinze, St Vincentius
# 2             102101: PIT Stuivenberg
# 3       110001: PIT Lier, Heilig Hart
# 4  113001: PIT HEILIG HART ZIEKENHUIS
#
#                                               campus  \
# 0  Ziekenhuis/Hôpital: 104 - AZ RIVIERENLAND --- ...
# 1  Ziekenhuis/Hôpital: 134 - AZ SINT-VINCENTIUS -...
# 2  Ziekenhuis/Hôpital: 009 - ZIEKENHUISNETWERK AN...
# 3  Ziekenhuis/Hôpital: 097 - HEILIG HART ZIEKENHU...
# 4  Ziekenhuis/Hôpital: 102 - HEILIG HART ZIEKENHU...
#
#                             province              region    unit_id  ambucode  \
# 0                   Antwerpen/Anvers  Vlaanderen/Flandre  PARUMS01A       191
# 1  Oost-Vlaanderen/Flandre orientale  Vlaanderen/Flandre  PODEIN01A       413
# 2                   Antwerpen/Anvers  Vlaanderen/Flandre  PAANTW01A       117
# 3                   Antwerpen/Anvers  Vlaanderen/Flandre  PALIER01A       171
# 4                   Antwerpen/Anvers  Vlaanderen/Flandre  PAMOL_01A       190
#
#    ambusitecode  link
# 0         19101  None
# 1         41301  None
# 2         11704  None
# 3         17101  None
# 4         19001  None

# %%
###############################################################################
# 0. check the variables and nan's
# print(interventions_bxl.info())
print(interventions_bxl.columns)

###############################################################################
# 1. select potentially useful variables
# keys = ["postalcode_intervention", "latitude_intervention", "longitude_intervention",
#         "eventtype_firstcall", "eventLevel_firstcall", "eventtype_trip",
#         "eventlevel_trip", "t0", "t3", "waiting_time"]
keys = ["postalcode_intervention", "latitude_intervention", "longitude_intervention",
        "eventtype_firstcall", "eventLevel_firstcall", "eventtype_trip",
        "eventlevel_trip", "waiting_time"]
interventions_bxl_1 = interventions_bxl[keys]

###############################################################################
# 2. drop data with nan's
interventions_bxl_2 = interventions_bxl_1.dropna()

###############################################################################
# 3. check event type
# 999 cases' event type changed on trip compared with on first call
# print((interventions_bxl_2["eventtype_firstcall"] != \
#        interventions_bxl_2["eventtype_trip"]).sum())

# related to heart: "P011 - Chest pain", "P039 - Cardiac problem
#  (other than thoracic pain)", "P003 - Cardiac arrest"
# need AED: "P003 - Cardiac arrest"
# print(interventions_bxl_2["eventtype_firstcall"].unique())
heart_related = ["P011 - Chest pain",
                 "P039 - Cardiac problem (other than thoracic pain)",
                 "P003 - Cardiac arrest"]
interventions_bxl_3 = interventions_bxl_2[interventions_bxl_2\
                      ["eventtype_firstcall"].isin(heart_related)]
# print(interventions_bxl_3) # 6358 × 6

###############################################################################
# 4. compare event type and level at the first call and at the trip
# 78 changed event type & 490 changed event level
# use the ones of first call because people who pass by the patient may not be able to distinguish
# levels generally decreases
# print((interventions_bxl_3["eventtype_firstcall"] != \
#        interventions_bxl_3["eventtype_trip"]).sum())
# print((interventions_bxl_3["eventLevel_firstcall"] != \
#        interventions_bxl_3["eventlevel_trip"]).sum())
# print(interventions_bxl_3[["eventtype_firstcall", "eventtype_trip"]]\
#                           [interventions_bxl_3["eventtype_firstcall"] != \
#                            interventions_bxl_3["eventtype_trip"]])
# print(interventions_bxl_3[["eventLevel_firstcall", "eventlevel_trip"]]\
#                           [interventions_bxl_3["eventLevel_firstcall"] != \
#                            interventions_bxl_3["eventlevel_trip"]])

# check event levels
level = interventions_bxl_3["eventLevel_firstcall"].apply(lambda x: int(x[1:]))
interventions_bxl_4 = interventions_bxl_3.assign(level_num = level)
# print(interventions_bxl_4)

###############################################################################
# 5. delete outliers in waiting_time
# define the function to delete outliers in a numeric variable
def delete_outliers(dataframe, column_name, threshold = 2):
  # data is a column of dataframe
  data = dataframe[column_name]
  m = data.mean()
  sd  = data.std()
  return dataframe[(data - m).abs() < threshold * sd]

# some waiting time is more than 20 hours, 1 is 999999999.0, which do not make sense
interventions_bxl_5 = interventions_bxl_4[interventions_bxl_4["waiting_time"] < 200]
# print(interventions_bxl_5)

###############################################################################
# 6. delete outliers in latitude & longtitude
# brussels: 50.8467°N 4.3525°E
interventions_bxl_6 = interventions_bxl_5[\
                      (interventions_bxl_5["latitude_intervention"] > 4500000) &\
                      (interventions_bxl_5["latitude_intervention"] < 5500000) &\
                      (interventions_bxl_5["longitude_intervention"] > 400000) &\
                      (interventions_bxl_5["longitude_intervention"] < 500000)]
# print(interventions_bxl_6) # 5156 x 9

###############################################################################
# 7. change the scale of latitude & longtitude
interventions_bxl_7 = interventions_bxl_6
interventions_bxl_7["latitude_intervention"] = \
                   interventions_bxl_6["latitude_intervention"].div(100000)
interventions_bxl_7["longitude_intervention"] = \
                   interventions_bxl_6["longitude_intervention"].div(100000)
print(interventions_bxl_7)
# Out:
# Index(['mission_id', 'service_name', 'postalcode_permanence',
#        'cityname_permanence', 'streetname_permanence',
#        'housenumber_permanence', 'latitude_permanence', 'longitude_permanence',
#        'permanence_short_name', 'permanence_long_name', 'vector_type',
#        'eventtype_firstcall', 'eventLevel_firstcall', 'eventtype_trip',
#        'eventlevel_trip', 'postalcode_intervention', 'cityname_intervention',
#        'latitude_intervention', 'longitude_intervention', 't0', 't1',
#        't1confirmed', 't2', 't3', 't4', 't5', 't6', 't7', 't9',
#        'intervention_time_t1reported', 'waiting_time', 'intervention_duration',
#        'departure_time_t1reported', 'unavailable_time',
#        'name_destination_hospital', 'postalcode_destination_hospital',
#        'cityname_destination_hospital', 'streetname_destination_hospital',
#        'housenumber_destination_hospital', 'calculated_traveltime_departure_',
#        'calculated_distance_departure_to', 'calculated_traveltime_destinatio',
#        'calculated_distance_destination_', 'number_of_transported_persons',
#        'abandon_reason'],
#       dtype='object')
#         postalcode_intervention  latitude_intervention  \
# 28                       1140.0               50.87798
# 44                       1020.0               50.89578
# 94                       1200.0               50.85592
# 95                       1200.0               50.85592
# 110                      1180.0               50.80938
# ...                         ...                    ...
# 115427                   1030.0               50.86312
# 115428                   1030.0               50.86312
# 115449                   1200.0               50.85177
# 115451                   1030.0               50.86312
# 115499                   1150.0               50.83178
#
#         longitude_intervention  \
# 28                     4.39229
# 44                     4.35817
# 94                     4.42592
# 95                     4.42592
# 110                    4.34743
# ...                        ...
# 115427                 4.37195
# 115428                 4.37195
# 115449                 4.43919
# 115451                 4.37195
# 115499                 4.43985
#
#                                       eventtype_firstcall  \
# 28                                      P011 - Chest pain
# 44                                      P011 - Chest pain
# 94                                      P011 - Chest pain
# 95                                      P011 - Chest pain
# 110                                     P011 - Chest pain
# ...                                                   ...
# 115427  P039 - Cardiac problem (other than thoracic pain)
# 115428  P039 - Cardiac problem (other than thoracic pain)
# 115449  P039 - Cardiac problem (other than thoracic pain)
# 115451  P039 - Cardiac problem (other than thoracic pain)
# 115499  P039 - Cardiac problem (other than thoracic pain)
#
#        eventLevel_firstcall  \
# 28                       N1
# 44                       N3
# 94                       N1
# 95                       N1
# 110                      N3
# ...                     ...
# 115427                   N1
# 115428                   N1
# 115449                   N1
# 115451                   N5
# 115499                   N5
#
#                                            eventtype_trip eventlevel_trip  \
# 28                                      P011 - Chest pain              N1
# 44                                      P011 - Chest pain              N3
# 94                                      P011 - Chest pain              N1
# 95                                      P011 - Chest pain              N1
# 110                                     P011 - Chest pain              N3
# ...                                                   ...             ...
# 115427  P039 - Cardiac problem (other than thoracic pain)              N1
# 115428  P039 - Cardiac problem (other than thoracic pain)              N1
# 115449  P039 - Cardiac problem (other than thoracic pain)              N1
# 115451  P039 - Cardiac problem (other than thoracic pain)              N5
# 115499  P039 - Cardiac problem (other than thoracic pain)              N5
#
#         waiting_time  level_num
# 28               9.0          1
# 44              57.0          3
# 94              14.0          1
# 95              38.0          1
# 110             14.0          3
# ...              ...        ...
# 115427           8.0          1
# 115428          18.0          1
# 115449          15.0          1
# 115451           9.0          5
# 115499          11.0          5
#
# [5156 rows x 9 columns]
# C:\Users\u0163298\AppData\Local\Temp\ipykernel_18716\718859985.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interventions_bxl_7["latitude_intervention"] = \
# C:\Users\u0163298\AppData\Local\Temp\ipykernel_18716\718859985.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interventions_bxl_7["longitude_intervention"] = \

# %%
aed_location= aed_locations

# %%
###############################################################################
# 0. check the variables and nan's
# print(aed_location.info())
# print(aed_location["address"])
# print(aed_location) # 15225 × 11

###############################################################################
# 1. only keep data in brussels
aed_location_1 = aed_location[aed_location["province"] == "Bruxelles-Brussel"]
# print(aed_location_1) # 2042 x 11

# print(aed_location_1["number"].isna().sum()) # 209 are nan's

###############################################################################
# 2. add the latitude and the longitude of corresponding address
from geopy.geocoders import Nominatim
import time

def find_location(address, number, province = "Bruxelles-Brussel",
                  country = "Belgium"):
  full_address = "{} {}, {}, {}".format(int(number), address, province, country)
  geolocator = Nominatim(user_agent = "my_app")
  location = geolocator.geocode(full_address, timeout=None)
  if location:
    return location.latitude, location.longitude
  return float("nan")

# calculating the latitude and the longitude data
# cost ~20 min...
# do not delete print()!
# lat_and_lon = []
# for i in range(aed_location_1.shape[0]):
#   address = list(aed_location_1["address"])[i]
#   number_raw = list(aed_location_1["number"])[i]
#   if pd.isna(number_raw):
#     lat_and_lon.append(float("nan"))
#     print("index = {}".format(i)) # slow the speed
#     continue
#   number = int(number_raw)
#   rst = find_location(address, number)
#   lat_and_lon.append(rst)
#   print("index = {}".format(i))

# save_variable(lat_and_lon, wd + save_dir + "/lat_and_lon.txt")
lat_and_lon = load_variable("lat_and_lon.txt")

latitude = []
longitude = []
for item in lat_and_lon:
  if pd.isna(item):
    latitude.append(float("nan"))
    longitude.append(float("nan"))
  else:
    latitude.append(item[0])
    longitude.append(item[1])

aed_location_2 = aed_location_1.assign(latitude = latitude,
                                       longitude = longitude)
# print(aed_location_2)

###############################################################################
# 3. only keep latitude & longitude data
keys = ["id", "postal_code", "latitude", "longitude", 'address']
aed_location_3 = aed_location_2[keys]

###############################################################################
# 4. drop data with nan's
aed_location_4 = aed_location_3.dropna()
print(aed_location_4) # 1562 x 4
# Out:
#             id  postal_code   latitude  longitude                 address
# 11        86.0       1040.0  50.842792   4.384351            Schumanplein
# 14        96.0       1090.0  50.882962   4.335248  Graafschap - Jettelaan
# 18       101.0       1070.0  50.831942   4.328980      Tweestationsstraat
# 60       315.0       1040.0  50.845150   4.369893               Wetstraat
# 69       335.0       1130.0  50.884114   4.419841      Chaussée de Haecht
# ...        ...          ...        ...        ...                     ...
# 15084  16518.0       1030.0  50.865560   4.378253        Rue de Jerusalem
# 15092  16526.0       1000.0  50.849255   4.363412          Koningsstraat
# 15192  16629.0       1210.0  50.855420   4.357981     Avenue du Boulevard
# 15204  16643.0       1070.0  50.815393   4.294843     Avenue Emile Gryson
# 15225  16666.0       1050.0  50.821723   4.362921     Albert Leemansplein
#
# [1562 rows x 5 columns]

# %%
import math

df = aed_location_2[["address", "number", "latitude", "longitude"]]
# x = list(df["latitude"])
# for i in range(1, len(x)):
#   if abs(x[i] - x[i - 1]) < 1e-8:
#     print("{}: ({}, {})".format(i, x[i], x[i-1]))
df.iloc[53:57, :]
# Out:
#           address  number   latitude  longitude
# 320   Bourgetlaan    42.0  50.877313   4.432468
# 321  Bourgetlaan     42.0  50.877313   4.432468
# 322  Bourgetlaan     42.0  50.877313   4.432468
# 327     Woluwedal   102.0  50.855719   4.444934

# %%
aed_location_4
# Out:
#             id  postal_code   latitude  longitude                 address
# 22              0.0  (Avenue De Fré - De Frélaan, Stalle, Uccle - U...
# 23              0.0  (Avenue Joseph Wybran - Joseph Wybranlaan, And...
#
#                                             end_point
# 0   (Avenue De Fré - De Frélaan, Stalle, Uccle - U...
# 1   (Brussels / UCL, Avenue Hippocrate - Hippokrat...
# 2   (Avenue de l'Arbre Ballon - Dikkebeuklaan / Av...
# 3   (Avenue de l'Héliport - Helihavenlaan, Quartie...
# 4                                                 NaN
# 5   (Vrije Universiteit Brussel — Campus Jette, 10...
# 6   (Chaussée de Mons - Bergense Steenweg, Dansaer...
# 7   (Boulevard du Triomphe - Triomflaan, Cité Volt...
# 8   (Rue du Marais - Broekstraat, Quartier Marais-...
# 9   (Rue Charles Degroux - Charles Degrouxstraat, ...
# 10  (Chaussée de Haecht - Haachtsesteenweg, Haren,...
# 11  (Avenue Hippocrate - Hippokrateslaan, Woluwe-S...
# 12  (Rue Jean Paquot - Jean Paquotstraat, Quartier...
# 13  (Vrije Universiteit Brussel — Campus Jette, 10...
# 14  (Rue Bruyn - Bruynstraat, Neder-Over-Heembeek,...
# 15  (Rue Haute - Hoogstraat, Marolles - Marollen, ...
# 16  (Rue Haute - Hoogstraat, Marolles - Marollen, ...
# 17  (Rue Jean Paquot - Jean Paquotstraat, Quartier...
# 18  (Rue Marconi - Marconistraat, Altitude Cent - ...
# 19  (Boulevard du Triomphe - Triomflaan, Cité Volt...
# 20  (Rue Vésale - Vesaliusstraat, Quartier Marais-...
# 21  (Avenue Britsiers - Britsierslaan, Terdelt, Sc...
# 22  (Avenue De Fré - De Frélaan, Stalle, Uccle - U...
# 23  (Avenue Joseph Wybran - Joseph Wybranlaan, And...

# %%
aed_location_4
# Out:
#             id  postal_code   latitude  longitude                 address
# 11        86.0       1040.0  50.842792   4.384351            Schumanplein
# 14        96.0       1090.0  50.882962   4.335248  Graafschap - Jettelaan
# 18       101.0       1070.0  50.831942   4.328980      Tweestationsstraat
# 60       315.0       1040.0  50.845150   4.369893               Wetstraat
# 69       335.0       1130.0  50.884114   4.419841      Chaussée de Haecht
# ...        ...          ...        ...        ...                     ...
# 15084  16518.0       1030.0  50.865560   4.378253        Rue de Jerusalem
# 15092  16526.0       1000.0  50.849255   4.363412          Koningsstraat
# 15192  16629.0       1210.0  50.855420   4.357981     Avenue du Boulevard
# 15204  16643.0       1070.0  50.815393   4.294843     Avenue Emile Gryson
# 15225  16666.0       1050.0  50.821723   4.362921     Albert Leemansplein
#
# [1562 rows x 5 columns]

# %%
from sklearn.metrics.pairwise import haversine_distances
from math import radians

# Remove rows with missing values from both DataFrames
critical_points_clean = critical_points.dropna(subset=['midpoint_coordinates'])
aed_location_4_clean = aed_location_4.dropna(subset=['latitude', 'longitude'])

# Convert latitude and longitude from degrees to radians
critical_points_clean['midpoint_coordinates_rad'] = critical_points_clean['midpoint_coordinates'].apply(lambda x: [radians(coord) for coord in x])
aed_location_4_clean['coordinates_rad'] = aed_location_4_clean.apply(lambda row: [radians(row['latitude']), radians(row['longitude'])], axis=1)

# Check if there are still missing values after cleaning
if critical_points_clean.isnull().values.any() or aed_location_4_clean.isnull().values.any():
    print("Error: Missing values remain after cleaning.")
else:
    # Calculate Haversine distances between critical points and candidate points
    distances = haversine_distances(critical_points_clean['midpoint_coordinates_rad'].tolist(), aed_location_4_clean['coordinates_rad'].tolist())

    # Find the closest candidate point for each critical point
    closest_distances = distances.min(axis=1)
    closest_candidate_indices = distances.argmin(axis=1)

    # Update critical_points DataFrame with closest candidate distance and index
    critical_points_clean['closest_candidate_distance'] = closest_distances * 6371  # Multiply by Earth's radius to get distance in kilometers
    critical_points_clean['closest_candidate_index'] = closest_candidate_indices
# Out:
# C:\Users\u0163298\AppData\Local\Temp\ipykernel_18716\2035838975.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   critical_points_clean['midpoint_coordinates_rad'] = critical_points_clean['midpoint_coordinates'].apply(lambda x: [radians(coord) for coord in x])
# C:\Users\u0163298\AppData\Local\Temp\ipykernel_18716\2035838975.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   critical_points_clean['closest_candidate_distance'] = closest_distances * 6371  # Multiply by Earth's radius to get distance in kilometers
# C:\Users\u0163298\AppData\Local\Temp\ipykernel_18716\2035838975.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   critical_points_clean['closest_candidate_index'] = closest_candidate_indices

# %%
critical_points_clean
# Out:
#                   streetname_permanence  initial_count  \
# 0            Avenue De FrÈ - De FrÈlaan            318
# 1   Avenue Hippocrate - Hippokrateslaan            268
# 2              Avenue de l'Arbre Ballon            315
# 3                  Avenue de l'HÈliport            807
# 5     Avenue du Laerbeek - Laarbeeklaan            162
# 6                     Bergense Steenweg            664
# 7                 Boulevard du Triomphe            464
# 8                           Broekstraat            245
# 9                 Charles Degrouxstraat            118
# 10                   ChaussÈe de Haecht            552
# 11                      Hippokrateslaan            183
# 12                    Jean Paquotstraat            411
# 13                         Laarbeeklaan            435
# 14                            Rue Bruyn            163
# 15                            Rue Haute            486
# 16               Rue Haute - Hoogstraat            850
# 17                      Rue Jean Paquot            212
# 18                          Rue Marconi            175
# 19                           Triomflaan            176
# 20                       Vesaliusstraat            391
# 21       avenue britsiers;britsierslaan            381
# 22                           de frÈlaan            175
# 23                    joseph wybranlaan            217
#
#     late_interventions_count  average_speed    average_time_difference  \
# 0                        111       4.606633  0 days 00:17:24.561550093
# 1                         82       3.722012  0 days 00:32:23.670930279
# 2                         45       4.666605  0 days 00:13:27.738957354
# 3                        140       3.479987  0 days 00:16:58.442625852
# 5                         65       5.728057  0 days 00:16:54.900619440
# 6                        106       3.578969  0 days 00:20:40.491780417
# 7                         90       3.788297  0 days 00:14:32.322593765
# 8                         72       4.097009  0 days 00:15:09.900237107
# 9                         29       2.751265  0 days 00:30:01.388118609
# 10                        76       3.658295  0 days 00:22:06.379834910
# 11                        46       4.639915  0 days 00:15:02.803091987
# 12                       140       5.146149  0 days 00:26:02.142937206
# 13                       138       5.133995  0 days 00:16:58.219077133
# 14                        55       6.085468  0 days 00:15:03.473604853
# 15                        84       2.547379  0 days 00:22:18.267702187
# 3                      1156
# 5                       635
# 6                       142
# 7                       184
# 8                      1314
# 9                        51
# 10                        4
# 11                       42
# 12                     1127
# 13                      635
# 14                      280
# 15                      232
# 16                      232
# 17                     1127
# 18                     1013
# 19                      184
# 20                      532
# 21                      291
# 22                      116
# 23                     1491

# %%
df_clusters = load_variable("df_clusters.txt")
df_clusters_all_nodes_haversine = load_variable("df_clusters_all_nodes_haversine.txt")
cluster_centers = load_variable("cluster_centers.txt")

# %%
df_clusters_all_nodes_haversine

# %%
cluster_centers
# Out:
#       cluster  latitude_intervention  longitude_intervention
# 0           0              50.835390                4.316295
# 1           1              50.862820                4.390080
# 2           2              50.814988                4.368908
# 3           3              50.888980                4.317545
# 4           4              50.815910                4.436210
# ...       ...                    ...                     ...
# 1557     1557              50.851402                4.320566
# 1558     1558              50.837935                4.285310
# 1559     1559              50.841840                4.467120
# 1560     1560              50.825910                4.305810
# 1561     1561              50.894343                4.417517
#
# [1562 rows x 3 columns]

# %%
from sklearn.metrics.pairwise import haversine_distances
from math import radians

# Remove rows with missing values from both DataFrames
#critical_points_clean = critical_points.dropna(subset=['midpoint_coordinates'])
df_clusters_all_nodes_haversine = df_clusters_all_nodes_haversine.dropna(subset=['node_latitude', 'node_longitude'])

# Convert latitude and longitude from degrees to radians
critical_points_clean['midpoint_coordinates_rad'] = critical_points_clean['midpoint_coordinates'].apply(lambda x: [radians(coord) for coord in x])
df_clusters_all_nodes_haversine['coordinates_rad'] = df_clusters_all_nodes_haversine.apply(lambda row: [radians(row['node_latitude']), radians(row['node_longitude'])], axis=1)

# Check if there are still missing values after cleaning
if critical_points_clean.isnull().values.any() or df_clusters_all_nodes_haversine.isnull().values.any():
    print("Error: Missing values remain after cleaning.")
else:
    # Calculate Haversine distances between critical points and candidate points
    distances = haversine_distances(critical_points_clean['midpoint_coordinates_rad'].tolist(), df_clusters_all_nodes_haversine['coordinates_rad'].tolist())

    # Find the closest candidate point for each critical point
    closest_distances = distances.min(axis=1)
    closest_candidate_indices = distances.argmin(axis=1)

    # Update critical_points DataFrame with closest candidate distance and index
    critical_points_clean['closest_candidate_distance_after'] = closest_distances * 6371  # Multiply by Earth's radius to get distance in kilometers
    critical_points_clean['closest_candidate_index_after'] = closest_candidate_indices
# Out:
# C:\Users\u0163298\AppData\Local\Temp\ipykernel_18716\2269893168.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   critical_points_clean['midpoint_coordinates_rad'] = critical_points_clean['midpoint_coordinates'].apply(lambda x: [radians(coord) for coord in x])
# C:\Users\u0163298\AppData\Local\Temp\ipykernel_18716\2269893168.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   critical_points_clean['closest_candidate_distance_after'] = closest_distances * 6371  # Multiply by Earth's radius to get distance in kilometers
# C:\Users\u0163298\AppData\Local\Temp\ipykernel_18716\2269893168.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 17  (Rue Jean Paquot - Jean Paquotstraat, Quartier...
# 18  (Rue Marconi - Marconistraat, Altitude Cent - ...
# 19  (Boulevard du Triomphe - Triomflaan, Cité Volt...
# 20  (Rue Vésale - Vesaliusstraat, Quartier Marais-...
# 21  (Avenue Britsiers - Britsierslaan, Terdelt, Sc...
# 22  (Avenue De Fré - De Frélaan, Stalle, Uccle - U...
# 23  (Avenue Joseph Wybran - Joseph Wybranlaan, And...
#
#                      midpoint_coordinates_rad  closest_candidate_distance  \
# 0   [0.8866823670389219, 0.07576934875296987]                    0.238565
# 1   [0.8875534163626962, 0.07772929328910029]                    0.158783
# 2   [0.8882515541721465, 0.07534018276187997]                    0.834109
# 3   [0.8877497126710036, 0.07602121023600816]                    0.153142
# 5   [0.8881425313077559, 0.07518123423121557]                    0.000000
# 6    [0.8874043434279604, 0.0757087037974508]                    0.000000
# 7    [0.886929434102505, 0.07681533679099482]                    0.115694
# 8   [0.8875462160068672, 0.07609672539675419]                    0.036115
# 9   [0.8873529958413666, 0.07679526201393838]                    0.219002
# 10  [0.8880906383057711, 0.07715519428426017]                    0.065170
# 11  [0.8875963854962158, 0.07759104314105594]                    0.053918
# 12  [0.8870537172532101, 0.07644343505266286]                    0.324083
# 13  [0.8881425313077559, 0.07518123423121557]                    0.000000
# 14  [0.8884257380314955, 0.07655860409401422]                    0.640105
# 15  [0.8873577518635783, 0.07595843074281391]                    0.097174
# 16  [0.8873577518635783, 0.07595843074281391]                    0.097174
# 17  [0.8870537172532101, 0.07644343505266286]                    0.324083
# 18  [0.8869426043570405, 0.07578874459694727]                    0.180259
# 19   [0.886929434102505, 0.07681533679099482]                    0.115694
# 20  [0.8875174302915141, 0.07616499918643371]                    0.055811
# 21  [0.8878263291345075, 0.07653693583135071]                    0.181585
# 22  [0.8866823670389219, 0.07576934875296987]                    0.238565
# 23  [0.8868943093513086, 0.07438503038477505]                    0.184234
#
#     closest_candidate_index  closest_candidate_distance_after  \
# 0                       116                          0.064397
# 1                       757                          0.357337
# 2                      1320                          0.076178
# 3                      1156                          0.090070
# 5                       635                          0.314567
# 6                       142                          0.043268
# 7                       184                          0.151169
# 8                      1314                          0.113969
# 9                        51                          0.085960
# 10                        4                          0.190465
# 11                       42                          0.037419
# 12                     1127                          0.119210
# 13                      635                          0.314567
# 14                      280                          0.084042
# 15                      232                          0.071796
# 16                      232                          0.071796
# 17                     1127                          0.119210
# 18                     1013                          0.040845
# 19                      184                          0.151169
# 20                      532                          0.015546
# 21                      291                          0.025772
# 22                      116                          0.064397
# 23                     1491                          0.234318
#
#     closest_candidate_index_after
# 0                            2862
# 1                            3999
# 2                            1363
# 3                            1708
# 5                            3322
# 6                             606
# 7                              75
# 8                             775
# 9                            4985
# 10                            541
# 11                            146
# 12                           1568
# 13                           3322
# 14                           2429
# 15                            137
# 16                            137
# 17                           1568
# 18                             55
# 19                             75
# 20                            207
# 21                           3930
# 22                           2862
# 23                            136
